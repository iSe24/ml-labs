# %% [markdown]
# # Лабораторная работа №2
# ## Изучение библиотек обработки данных. Часть 1.
# Часть 1.
# Выполните первое демонстрационное задание "demo assignment" под названием "Exploratory data analysis with Pandas" со страницы курса https://mlcourse.ai/assignments

# %% [markdown]
# Объявление библиотек и настройка отображения:

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Подключение предлагаемой выборки и проверка выводом первых 5ти:

# %%
data = pd.read_csv('C:/jupWork2/data/adult.data.csv' )
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# Задача 1) Сколько мужчин и женщин отображено в выборке

# %%
#1. How many men and women (sex feature) are represented in this dataset?
data['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %% [markdown]
# Задача 2) Найти средний возраст женщин

# %%
#2. What is the average age (age feature) of women?
data_fem = data[data['sex']==' Female']
data_fem.head()
data_fem['age'].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# Задача 3) Каков процент жителей из Германии?

# %%
#3. What is the percentage of German citizens (native-country feature)? 
(data['native-country']==' Germany').sum()/data['age'].count()*100
# Out:
# 0.42074874850281013

# %% [markdown]
# Задачи 4-5) Найти среднее и отклонение возраста для богатых (ЗП>50к) и бедных (ЗП<50к)

# %%
#4-5. What are the mean and standard deviation of age for those who earn more than 50K per year (salary feature) and those who earn less than 50K per year?
ages1 = data.loc[data['salary'] == ' >50K', 'age']
ages2 = data.loc[data['salary'] == ' <=50K', 'age']
print("rich: {0} +- {1} years, \npoor: {2} +- {3} years.".format(
    round(ages1.mean()), round(ages1.std(), 1),
    round(ages2.mean()), round(ages2.std(), 1)))
# Out:
# rich: 44.0 +- 10.5 years,
# poor: 37.0 +- 14.0 years.

# %% [markdown]
# Задача 6) Проверить, является ли правдой утверждение что те, кто зарабатывает 50к+ имеют образование как минимум выше старшей школы?

# %%
#6. Is it true that people who earn more than 50K have at least high school education? (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature)
#data.loc[data['salary'] == ' >50K', 'education'].unique()
data.loc[(data['salary'] == ' >50K') & 
(~data['education'].isin([' Bachelors', ' Prof-school', ' Assoc-acdm',
 ' Assoc-voc', ' Masters',' Doctorate feature']))]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 10      37            Private  280464   Some-college             10
# 20      40            Private  193524      Doctorate             16
# 27      54                  ?  180211   Some-college             10
# 38      31            Private   84154   Some-college             10
# 55      43            Private  237993   Some-college             10
# 63      42            Private  116632      Doctorate             16
# 67      53            Private  169846        HS-grad              9
# 68      49       Self-emp-inc  191681   Some-college             10
# 84      44            Private  343591        HS-grad              9
# 86      49          Local-gov  268234        HS-grad              9
# 89      43        Federal-gov  410867      Doctorate             16
# 96      48   Self-emp-not-inc  191277      Doctorate             16
# 97      37            Private  202683   Some-college             10
# 105     32       Self-emp-inc  317660        HS-grad              9
# 112     56   Self-emp-not-inc  335605        HS-grad              9
# 139     49            Private   81973   Some-college             10
# 154     52                  ?  252903        HS-grad              9
# 172     51            Private   96062   Some-college             10
# 180     44          Local-gov  181344   Some-college             10
# 183     40            Private  286370        7th-8th              4
# 184     37        Federal-gov   29054   Some-college             10
# 189     58          State-gov  109567      Doctorate             16
# 208     58       Self-emp-inc  210563        HS-grad              9
# 211     37            Private  208358        HS-grad              9
# 214     54       Self-emp-inc  125417        7th-8th              4
# 246     58            Private  236596        HS-grad              9
# 255     42   Self-emp-not-inc  303044        HS-grad              9
# 265     37       Self-emp-inc  257295   Some-college             10
# 267     64            Private   21174        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32272   38            Private  447346   Some-college             10
# 32287   54          Local-gov   34832      Doctorate             16
# 32292   41            Private  318046   Some-college             10
# 32295   32            Private   33678   Some-college             10
# 32297   47            Private  160474        HS-grad              9
# 32302   45          Local-gov  162187        HS-grad              9
# 32305   34            Private  356882   Some-college             10
# 32308   37            Private  377798   Some-college             10
# 32326   48            Private  123075      Doctorate             16
# 32333   37       Self-emp-inc  328466   Some-college             10
# 32358   34            Private  115066   Some-college             10
# 32372   51            Private   40641   Some-college             10
# 32375   59            Private  395736        HS-grad              9
# 32386   59        Federal-gov   23789        HS-grad              9
# 32389   47            Private  248059   Some-college             10
# 32400   53          Local-gov  186303   Some-college             10
# 32402   42            Private  288154   Some-college             10
# 32415   57   Self-emp-not-inc   65080        HS-grad              9
# 32429   51          Local-gov  203334      Doctorate             16
# 32440   30   Self-emp-not-inc  176185   Some-college             10
# 32441   53            Private  304504   Some-college             10
# 32453   46            Private   42251   Some-college             10
# 32462   48       Self-emp-inc  185041        HS-grad              9
# 32510   39            Private  107302        HS-grad              9
# 32518   57          Local-gov  110417        HS-grad              9
# 32519   46            Private  364548   Some-college             10
# 32532   34            Private  204461      Doctorate             16
# 32539   71                  ?  287372      Doctorate             16
# 32557   40            Private  154374        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation    relationship  \
# 7          Married-civ-spouse     Exec-managerial         Husband
# 10         Married-civ-spouse     Exec-managerial         Husband
# 20         Married-civ-spouse      Prof-specialty         Husband
# 27         Married-civ-spouse                   ?         Husband
# 38         Married-civ-spouse               Sales         Husband
# 55         Married-civ-spouse        Tech-support         Husband
# 63         Married-civ-spouse      Prof-specialty         Husband
# 67         Married-civ-spouse        Adm-clerical            Wife
# 68         Married-civ-spouse     Exec-managerial         Husband
# 84                   Divorced        Craft-repair   Not-in-family
# 86         Married-civ-spouse     Protective-serv         Husband
# 89              Never-married      Prof-specialty   Not-in-family
# 96         Married-civ-spouse      Prof-specialty         Husband
# 97         Married-civ-spouse               Sales         Husband
# 105        Married-civ-spouse        Craft-repair         Husband
# 112        Married-civ-spouse       Other-service         Husband
# 139        Married-civ-spouse        Craft-repair         Husband
# 154                  Divorced                   ?   Not-in-family
# 172        Married-civ-spouse               Sales         Husband
# 180        Married-civ-spouse     Exec-managerial         Husband
# 183        Married-civ-spouse   Machine-op-inspct         Husband
# 184        Married-civ-spouse        Adm-clerical         Husband
# 189        Married-civ-spouse      Prof-specialty         Husband
# 208        Married-civ-spouse               Sales            Wife
# 211        Married-civ-spouse        Craft-repair         Husband
# 214        Married-civ-spouse   Machine-op-inspct         Husband
# 246        Married-civ-spouse        Adm-clerical         Husband
# 255        Married-civ-spouse     Farming-fishing         Husband
# 265        Married-civ-spouse     Exec-managerial         Husband
# 267        Married-civ-spouse     Exec-managerial         Husband
# ...                       ...                 ...             ...
# 32272      Married-civ-spouse        Craft-repair         Husband
# 32287      Married-civ-spouse     Exec-managerial         Husband
# 32292      Married-civ-spouse    Transport-moving         Husband
# 32295      Married-civ-spouse    Transport-moving         Husband
# 32297      Married-civ-spouse     Exec-managerial            Wife
# 32302      Married-civ-spouse     Protective-serv         Husband
# 32305      Married-civ-spouse               Sales         Husband
# 32308      Married-civ-spouse        Craft-repair         Husband
# 32326      Married-civ-spouse      Prof-specialty         Husband
# 32333      Married-civ-spouse     Exec-managerial         Husband
# 32358      Married-civ-spouse     Exec-managerial         Husband
# 32372      Married-civ-spouse     Exec-managerial         Husband
# 32375      Married-civ-spouse   Handlers-cleaners         Husband
# 32386      Married-civ-spouse               Sales            Wife
# 32389      Married-civ-spouse       Other-service         Husband
# 32400      Married-civ-spouse     Protective-serv         Husband
# 32402      Married-civ-spouse        Craft-repair         Husband
# 32415      Married-civ-spouse        Craft-repair         Husband
# 32429                Divorced     Exec-managerial   Not-in-family
# 32440   Married-spouse-absent        Craft-repair       Own-child
# 32441      Married-civ-spouse    Transport-moving         Husband
# 32453      Married-civ-spouse               Sales         Husband
# 32462      Married-civ-spouse        Craft-repair         Husband
# 32510      Married-civ-spouse      Prof-specialty         Husband
# 32518      Married-civ-spouse        Craft-repair         Husband
# 32519      Married-civ-spouse     Exec-managerial         Husband
# 32532      Married-civ-spouse      Prof-specialty         Husband
# 32539      Married-civ-spouse                   ?         Husband
# 32557      Married-civ-spouse   Machine-op-inspct         Husband
# 32560      Married-civ-spouse     Exec-managerial            Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 7                    White     Male             0             0
# 10                   Black     Male             0             0
# 20                   White     Male             0             0
# 27      Asian-Pac-Islander     Male             0             0
# 38                   White     Male             0             0
# 55                   White     Male             0             0
# 63                   White     Male             0             0
# 67                   White   Female             0             0
# 68                   White     Male             0             0
# 84                   White   Female         14344             0
# 86                   White     Male             0             0
# 89                   White   Female             0             0
# 96                   White     Male             0          1902
# 97                   White     Male             0             0
# 105                  White     Male          7688             0
# 112                  White     Male             0          1887
# 139     Asian-Pac-Islander     Male             0             0
# 154                  White     Male             0             0
# 172                  White     Male             0          1977
# 180                  Black     Male             0             0
# 183                  White     Male             0             0
# 184                  White     Male             0             0
# 189                  White     Male             0             0
# 208                  White   Female         15024             0
# 211                  White     Male             0             0
# 214                  White     Male             0             0
# 246                  White     Male             0             0
# 255     Asian-Pac-Islander     Male             0             0
# 265     Asian-Pac-Islander     Male             0             0
# 267                  White     Male             0             0
# ...                    ...      ...           ...           ...
# 32272                White     Male             0             0
# 32287                White     Male             0             0
# 32292                White     Male             0             0
# 32295                White     Male             0             0
# 32297                White   Female             0             0
# 32302                White     Male             0             0
# 32305                White     Male             0             0
# 32308                White     Male          3103             0
# 32326                White     Male             0             0
# 32333                White     Male             0             0
# 32358                White     Male             0             0
# 32372                White     Male             0             0
# 32375                White     Male             0             0
# 32386                White   Female             0             0
# 32389                White     Male             0             0
# 32400                White     Male             0          1887
# 32402                White     Male             0             0
# 32415                White     Male             0             0
# 32429                White   Female             0             0
# 32440                White     Male             0             0
# 32441                White     Male             0          1887
# 32453                White     Male             0             0
# 32462                White     Male          7298             0
# 32510                White     Male             0             0
# 32518                White     Male         99999             0
# 32519                White     Male             0             0
# 32532                White     Male             0             0
# 32539                White     Male             0             0
# 32557                White     Male             0             0
# 32560                White   Female         15024             0
#
#        hours-per-week  native-country salary
# 7                  45   United-States   >50K
# 10                 80   United-States   >50K
# 20                 60   United-States   >50K
# 27                 60           South   >50K
# 38                 38               ?   >50K
# 55                 40   United-States   >50K
# 63                 45   United-States   >50K
# 67                 40   United-States   >50K
# 68                 50   United-States   >50K
# 84                 40   United-States   >50K
# 86                 40   United-States   >50K
# 89                 50   United-States   >50K
# 96                 60   United-States   >50K
# 97                 48   United-States   >50K
# 105                40   United-States   >50K
# 112                50          Canada   >50K
# 139                40   United-States   >50K
# 154                45   United-States   >50K
# 172                40   United-States   >50K
# 180                38   United-States   >50K
# 183                40          Mexico   >50K
# 184                42   United-States   >50K
# 189                 1   United-States   >50K
# 208                35   United-States   >50K
# 211                40   United-States   >50K
# 214                40   United-States   >50K
# 246                45   United-States   >50K
# 255                40        Cambodia   >50K
# 265                75        Thailand   >50K
# 267                40   United-States   >50K
# ...               ...             ...    ...
# 32272              36   United-States   >50K
# 32287              60   United-States   >50K
# 32292              48   United-States   >50K
# 32295              50   United-States   >50K
# 32297              30   United-States   >50K
# 32302              40   United-States   >50K
# 32305              45   United-States   >50K
# 32308              40   United-States   >50K
# 32326              45   United-States   >50K
# 32333              50   United-States   >50K
# 32358              42   United-States   >50K
# 32372              60   United-States   >50K
# 32375              40   United-States   >50K
# 32386              40   United-States   >50K
# 32389              47   United-States   >50K
# 32400              40   United-States   >50K
# 32402              89   United-States   >50K
# 32415              50   United-States   >50K
# 32429              45   United-States   >50K
# 32440              60   United-States   >50K
# 32441              45   United-States   >50K
# 32453              45   United-States   >50K
# 32462              50   United-States   >50K
# 32510              45               ?   >50K
# 32518              40   United-States   >50K
# 32519              48   United-States   >50K
# 32532              60   United-States   >50K
# 32539              10   United-States   >50K
# 32557              40   United-States   >50K
# 32560              40   United-States   >50K
#
# [3612 rows x 15 columns]

# %% [markdown]
# Задача 7) Отобразить возрастную статистику по каждой расе и полу. Использовать GROUPBY и DESCRIBE. Найти максимальный возраст мужчин Американско-Индийско-Эскимоской расы (?).

# %%
#7. Display age statistics for each race (race feature) and each gender (sex feature). Use groupby() and describe(). Find the maximum age of men of Amer-Indian-Eskimo race.
for (race, sex), sub_df in data.groupby(['race', 'sex']):
    print("Race: {0}, sex: {1}".format(race, sex))
    print(sub_df['age'].describe())
# Out:
# Race:  Amer-Indian-Eskimo, sex:  Female
# count    119.000000
# mean      37.117647
# std       13.114991
# min       17.000000
# 25%       27.000000
# 50%       36.000000
# 75%       46.000000
# max       80.000000
# Name: age, dtype: float64
# Race:  Amer-Indian-Eskimo, sex:  Male
# count    192.000000
# mean      37.208333
# std       12.049563
# min       17.000000
# 25%       28.000000
# 50%       35.000000
# 75%       45.000000
# max       82.000000
# Name: age, dtype: float64
# Race:  Asian-Pac-Islander, sex:  Female
# count    346.000000
# mean      35.089595
# std       12.300845
# min       17.000000
# 25%       25.000000
# 50%       33.000000
# 75%       43.750000
# max       75.000000
# Name: age, dtype: float64
# Race:  Asian-Pac-Islander, sex:  Male
# count    693.000000
# mean      39.073593
# std       12.883944
# min       18.000000
# 25%       29.000000
# 50%       37.000000
# 75%       46.000000
# max       90.000000
# Name: age, dtype: float64
# Race:  Black, sex:  Female
# count    1555.000000
# mean       37.854019
# std        12.637197
# min        17.000000
# 25%        28.000000
# 50%        37.000000
# 75%        46.000000
# max        90.000000
# Name: age, dtype: float64
# Race:  Black, sex:  Male
# count    1569.000000
# mean       37.682600
# std        12.882612
# min        17.000000
# 25%        27.000000
# 50%        36.000000
# 75%        46.000000
# max        90.000000
# Name: age, dtype: float64
# Race:  Other, sex:  Female
# count    109.000000
# mean      31.678899
# std       11.631599
# min       17.000000
# 25%       23.000000
# 50%       29.000000
# 75%       39.000000
# max       74.000000
# Name: age, dtype: float64
# Race:  Other, sex:  Male
# count    162.000000
# mean      34.654321
# std       11.355531
# min       17.000000
# 25%       26.000000
# 50%       32.000000
# 75%       42.000000
# max       77.000000
# Name: age, dtype: float64
# Race:  White, sex:  Female
# count    8642.000000
# mean       36.811618
# std        14.329093
# min        17.000000
# 25%        25.000000
# 50%        35.000000
# 75%        46.000000
# max        90.000000
# Name: age, dtype: float64
# Race:  White, sex:  Male
# count    19174.000000
# mean        39.652498
# std         13.436029
# min         17.000000
# 25%         29.000000
# 50%         38.000000
# 75%         49.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# Задача 8) Найти кого больше среди тех кто получает 50к+: женатых или одиноких мужчин

# %%
#8. Among whom the proportion of those who earn a lot(>50K) is more: among married or single men (marital-status feature)? Consider married those who have a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors.
data.loc[(data['sex'] == ' Male') &
     (data['marital-status'].isin([' Never-married', ' Separated', ' Divorced',
      ' Widowed'])), 'salary'].value_counts()
# Out:
#  <=50K    7552
#  >50K      697
# Name: salary, dtype: int64

# %% [markdown]
# Такое же сравнение но среди тех кто имеет в статусе "Семейное положение" статус начинающийся с 'married'

# %%
data.loc[(data['sex'] == ' Male') &
     (data['marital-status'].str.startswith(' Married')), 'salary'].value_counts()
# Out:
#  <=50K    7576
#  >50K     5965
# Name: salary, dtype: int64

# %% [markdown]
# Общая статистика по "Семейному положению"

# %%
data['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %% [markdown]
# Задание 9) Чему равно максимальное число отработанных в неделю часов? Сколько человек так живет и сколько из них получает много?

# %%
#9. What is the maximum number of hours a person works per week (hours-per-week feature)? How many people work such a number of hours and what is the percentage of those who earn a lot among them?
maxh = data['hours-per-week'].max()
num = data[data['hours-per-week'] == maxh].shape[0]
pers = float(data[(data['hours-per-week'] == maxh)
                 & (data['salary'] == ' >50K')].shape[0]) / num
print("There are {a} men with {b} hpw and there is a percentage of rich among them {c}%".format(a=num,b=maxh,c=int(100 * pers)))
# Out:
# There are 85 men with 99 hpw and there is a percentage of rich among them 29%

# %%
Задание 10) Найти среднее рабочее время относительно получающих больше/меньше 50к по каждой стране

# %%
#10. Count the average time of work (hours-per-week) those who earning a little and a lot (salary) for each country (native-country).
for (country, salary), sub_df in data.groupby(['native-country', 'salary']):
    print(country, salary, round(sub_df['hours-per-week'].mean(), 2))
# Out:
#  ?  <=50K 40.16
#  ?  >50K 45.55
#  Cambodia  <=50K 41.42
#  Cambodia  >50K 40.0
#  Canada  <=50K 37.91
#  Canada  >50K 45.64
#  China  <=50K 37.38
#  China  >50K 38.9
#  Columbia  <=50K 38.68
#  Columbia  >50K 50.0
#  Cuba  <=50K 37.99
#  Cuba  >50K 42.44
#  Dominican-Republic  <=50K 42.34
#  Dominican-Republic  >50K 47.0
#  Ecuador  <=50K 38.04
#  Ecuador  >50K 48.75
#  El-Salvador  <=50K 36.03
#  El-Salvador  >50K 45.0
#  England  <=50K 40.48
#  England  >50K 44.53
#  France  <=50K 41.06
#  France  >50K 50.75
#  Germany  <=50K 39.14
#  Germany  >50K 44.98
#  Greece  <=50K 41.81
#  Greece  >50K 50.62
#  Guatemala  <=50K 39.36
#  Guatemala  >50K 36.67
#  Haiti  <=50K 36.33
#  Haiti  >50K 42.75
#  Holand-Netherlands  <=50K 40.0
#  Honduras  <=50K 34.33
#  Honduras  >50K 60.0
#  Hong  <=50K 39.14
#  Hong  >50K 45.0
#  Hungary  <=50K 31.3
#  Hungary  >50K 50.0
#  India  <=50K 38.23
#  India  >50K 46.48
#  Iran  <=50K 41.44
#  Iran  >50K 47.5
#  Ireland  <=50K 40.95
#  Ireland  >50K 48.0
#  Italy  <=50K 39.62
#  Italy  >50K 45.4
#  Jamaica  <=50K 38.24
#  Jamaica  >50K 41.1
#  Japan  <=50K 41.0
#  Japan  >50K 47.96
#  Laos  <=50K 40.38
#  Laos  >50K 40.0
#  Mexico  <=50K 40.0
#  Mexico  >50K 46.58
#  Nicaragua  <=50K 36.09
#  Nicaragua  >50K 37.5
#  Outlying-US(Guam-USVI-etc)  <=50K 41.86
#  Peru  <=50K 35.07
#  Peru  >50K 40.0
#  Philippines  <=50K 38.07
#  Philippines  >50K 43.03
#  Poland  <=50K 38.17
#  Poland  >50K 39.0
#  Portugal  <=50K 41.94
#  Portugal  >50K 41.5
#  Puerto-Rico  <=50K 38.47
#  Puerto-Rico  >50K 39.42
#  Scotland  <=50K 39.44
#  Scotland  >50K 46.67
#  South  <=50K 40.16
#  South  >50K 51.44
#  Taiwan  <=50K 33.77
#  Taiwan  >50K 46.8
#  Thailand  <=50K 42.87
#  Thailand  >50K 58.33
#  Trinadad&Tobago  <=50K 37.06
#  Trinadad&Tobago  >50K 40.0
#  United-States  <=50K 38.8
#  United-States  >50K 45.51
#  Vietnam  <=50K 37.19
#  Vietnam  >50K 39.2
#  Yugoslavia  <=50K 41.6
#  Yugoslavia  >50K 49.5
